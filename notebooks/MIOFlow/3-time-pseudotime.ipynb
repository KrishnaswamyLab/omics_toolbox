# %% [markdown]
# # Time, Pseudotime and MioFlow preparation
#
# Prerequisites:
# - You have preprocessed your adata using dimentionaly reduction tools (PCA and PHATE) into the data/preprocessed directory. [notebook: 2-dim-reduction-latent-spaces]:
#     - gene values on _X_ (adata.X)
#     - phate embeddings of the data on _obsm_ (ex.: adata.obsm['X_phate])
#     - any extra metadata on _obs_ (ex.: adata.obs['time_label'], adata.obs['disease_progression'], etc...)
#
#
# In this notebook, we will:
# - Use the latent spaces to determine a time feature
# - In our case, since we have actual time labels, so no extra time-infering step is necessary.
# - Finally we will create python objects that are in the format expected by MIOFlow.
#
# - In other cases we can use different features to determine pseudotime (via Diffusion Pseudotime).

# %%
import numpy as np
import pandas as pd
import scprep
import scanpy as sc
import os

PROCESSED_DATA_DIR = os.path.join('../../data', 'processed')
print(PROCESSED_DATA_DIR)

# Load the adata object with the phate embeddings
adata = sc.read(os.path.join(PROCESSED_DATA_DIR, 'adata_phate.h5ad'))
adata
# Out:
# ../../data/processed
# AnnData object with n_obs × n_vars = 17944 × 18019
#     obs: 'time_label'
#     uns: 'pca'
#     obsm: 'X_pca', 'X_phate'
#     varm: 'PCs'

# %% [markdown]
# ## 1. Retrieve the time feature
# In our case the time feature is known and was stored under `adata.obs['time_label']`.
#
# If your data had another feature, like cell_cycle_phase under `adata.obs['cell_cycle']` you can use that as a way to calculate a pseudotime

# %% [markdown]
# First, let's verify our current PHATE plot

# %%
scprep.plot.scatter2d(adata.obsm['X_phate'], c=adata.obs['time_label'], cmap="Spectral",
                      ticks=False, label_prefix="PHATE")
# Out:
# /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# <Axes: xlabel='PHATE1', ylabel='PHATE2'>

# %% [markdown]
# # 2. Prepare Objects for MIOFlow

# %%
# 1. Prepare the results directory
data_name = 'scRNAseq'

RESULTS_DIR = os.path.join('../../results')
os.makedirs(RESULTS_DIR, exist_ok=True)

SAVE_PATH = os.path.join(RESULTS_DIR, data_name)
os.makedirs(SAVE_PATH, exist_ok=True)

# %% [markdown]
# First, we MIOFlow as described on the [documentation](https://github.com/KrishnaswamyLab/MIOFlow_conditional) needs data to be passed on a specific format:
#
# - Data needs to be passed as pandas DataFrames
# - Time labels need to be discrete integer values
# - Columns names needs to be d{i} (for every dimension on your data)

# %% [markdown]
# ### Discretizing time labels
#
# This step can be specific to the way you create the labels.
# - If your label is numeric, you can just bin using pd.cut().
# - If your label is - like our case - a pd.Categorical() object we can just bin it straight using factorize.

# %%
#First we will discretize the time labels
# adata.obs['discrete_time'] = pd.cut(adata.obs['dpt_pseudotime'], bins=10, labels=False)

# Create a numerical bin for each unique value
adata.obs['discrete_time'], _ = pd.factorize(adata.obs['time_label'])

# %% [markdown]
# ### Sanity Check to verify that the discrete times are in the correct order. This is important to properly infer trajectories

# %%
scprep.plot.scatter2d(adata.obsm['X_phate'], c=adata.obs['discrete_time'], cmap="Spectral",
                      ticks=False, label_prefix="PHATE")
# Out:
# /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# <Axes: xlabel='PHATE1', ylabel='PHATE2'>

# %% [markdown]
# Let's verify if all values are assigned in a correct label

# %%
print(adata.obs['discrete_time'].value_counts())
# Out:
# discrete_time
# 1    4443
# 3    3910
# 4    3563
# 2    3494
# 0    2534
# Name: count, dtype: int64

# %% [markdown]
# ### Creating the MIOFlow DataFrame

# %% [markdown]
# Here we will simply change the columns names to match the _d{i}_ format expected by MIOFlow and add the discretized samples

# %%
adata.obs['time_label']
# Out:
# AAACATTGAAGTGA-1_Day 00-03    Day 00-03
# AAACATTGGAGGTG-1_Day 00-03    Day 00-03
# AAACATTGGTTTCT-1_Day 00-03    Day 00-03
# AAACCGTGCAGAAA-1_Day 00-03    Day 00-03
# AAACGCACCGGTAT-1_Day 00-03    Day 00-03
#                                 ...
# TTTCTACTCTGATG-1_Day 24-27    Day 24-27
# TTTCTACTCTTATC-1_Day 24-27    Day 24-27
# TTTCTACTTGAGCT-1_Day 24-27    Day 24-27
# TTTGCATGATGACC-1_Day 24-27    Day 24-27
# TTTGCATGTTCTTG-1_Day 24-27    Day 24-27
# Name: time_label, Length: 17944, dtype: category
# Categories (5, object): ['Day 00-03', 'Day 06-09', 'Day 12-15', 'Day 18-21', 'Day 24-27']

# %%
# Create a dataframe with the phate embeddings as columns in the format d{i}
mioflow_df = pd.DataFrame(adata.obsm['X_phate'], columns=[f'd{i}' for i in range(1, adata.obsm['X_phate'].shape[1]+1)])

# Add the time labels to the dataframe as a column called 'samples' (this is expected by MIOFlow)
mioflow_df['samples'] = adata.obs['discrete_time'].values
mioflow_df
# Out:
#              d1        d2  samples
# 0     -0.034637 -0.008369        0
# 1     -0.031527 -0.003100        0
# 2     -0.025264  0.004984        0
# 3     -0.023847  0.006546        0
# 4     -0.042714 -0.024189        0
# ...         ...       ...      ...
# 17939  0.014378 -0.000495        4
# 17940  0.016304 -0.002059        4
# 17941  0.023092 -0.002598        4
# 17942  0.024944 -0.002936        4
# 17943  0.020479 -0.000949        4
#
# [17944 rows x 3 columns]

# %% [markdown]
# ### Finally we save the _mioflow_df_ to the results as well as save a new version of our adata object.

# %%
mioflow_df.to_csv(os.path.join(SAVE_PATH,'mioflow_data.csv'), index=False)

adata.write(os.path.join(PROCESSED_DATA_DIR, 'adata_mioflow.h5ad'))
adata
# Out:
# AnnData object with n_obs × n_vars = 17944 × 18019
#     obs: 'time_label', 'discrete_time'
#     uns: 'pca'
#     obsm: 'X_pca', 'X_phate'
#     varm: 'PCs'

# %% [markdown]
# # [OPTIONAL] 3. Inpute a time feature in our data using Diffusion PseudoTime.
#
# If your data doesn't have time labels you can try running different kind of algorithms to obtain a pseudotime transaction on it. In our example we recommend Diffusion Pseudotime.
#
# - Diffusion Pseudotime
#     - Select a cell as starting point.
#     - Returns a smooth time label for every cell on the manifold.

# %%
# Create a column to mark root vs non-root cells
# We need to define a root cell to use as a starting point for the DPT algorithm
target_phate1_position = -0.04  # Replace with your desired PHATE_1 value

# Find the cell closest to your target PHATE_1 position
phate1_values = adata.obsm['X_phate'][:, 0]  # PHATE_1 is the second column (index 1)
root_idx = np.argmin(np.abs(phate1_values - target_phate1_position))
# root_idx = np.argmin(adata.obsm['X_phate'][:, 0])


adata.obs['root_status'] = 'Other cells'
adata.obs.iloc[root_idx, adata.obs.columns.get_loc('root_status')] = 'Root cell'

# Plot with custom groups
sc.pl.embedding(adata, basis='phate', color='root_status', 
                title='Root Cell Location',
                palette={'Other cells': 'lightgray', 'Root cell': 'red'},
                size=60)

# %%
# Method 2: Use scanpy Difussion Pseudotime (DPT) on PHATE space

sc.pp.neighbors(adata, use_rep='X_phate', n_neighbors=200)
sc.tl.diffmap(adata)
adata.uns['iroot'] = root_idx
sc.tl.dpt(adata)


sc.pl.embedding(adata, basis='phate', color='dpt_pseudotime', 
                color_map='inferno', title='DPT on PHATE')

# %%
#We then discretize the time labels
adata.obs['discrete_pseudotime'] = pd.cut(adata.obs['dpt_pseudotime'], bins=30, labels=False)

# %%
scprep.plot.scatter2d(adata.obsm['X_phate'], c=adata.obs['discrete_pseudotime'], cmap="Spectral",
                      ticks=False, label_prefix="PHATE")
# Out:
# /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# <Axes: xlabel='PHATE1', ylabel='PHATE2'>

# %% [markdown]
# **Attention** only decommend this lines if you need to save the newly assigned discrete_pseudotime variables

# %%
#Save your new data
# adata.write(os.path.join(PROCESSED_DATA_DIR, 'adata_time.h5ad'))

# Save it in the format expected by MIOFlow

# mioflow_df = pd.DataFrame(adata.obsm['X_phate'], columns=[f'd{i}' for i in range(1, adata.obsm['X_phate'].shape[1]+1)])

# mioflow_df['samples'] = adata.obs['discrete_pseudotime'].values

# mioflow_df

# mioflow_df.to_csv(os.path.join(SAVE_PATH,'mioflow_data.csv'), index=False)

# adata.write(os.path.join(PROCESSED_DATA_DIR, 'adata_mioflow.h5ad'))
# adata
