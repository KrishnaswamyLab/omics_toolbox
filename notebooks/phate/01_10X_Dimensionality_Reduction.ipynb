# %%
# !pip install phate scprep scanpy gdown pandas==2.2.0
# Out:
# Requirement already satisfied: phate in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (1.0.11)
# Requirement already satisfied: scprep in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: scanpy in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (1.11.4)
# Requirement already satisfied: gdown in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (5.2.0)
# Requirement already satisfied: pandas==2.2.0 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from pandas==2.2.0) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from pandas==2.2.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from pandas==2.2.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from pandas==2.2.0) (2025.2)
# Requirement already satisfied: scipy>=1.1.0 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from phate) (1.15.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from phate) (1.7.1)
# Requirement already satisfied: future in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from phate) (1.0.0)
# Requirement already satisfied: tasklogger>=1.2 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from phate) (1.2.0)
# Requirement already satisfied: graphtools>=1.5.3 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from phate) (1.5.3)
# Requirement already satisfied: Deprecated in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from phate) (1.2.18)
# Requirement already satisfied: s-gd2>=1.8.1 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from phate) (1.8.1)
# Requirement already satisfied: matplotlib>=3.0 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from phate) (3.10.5)
# Requirement already satisfied: decorator>=4.3.0 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scprep) (5.2.1)
# Requirement already satisfied: packaging in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scprep) (25.0)
# Requirement already satisfied: anndata>=0.8 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (0.11.4)
# Requirement already satisfied: h5py>=3.7.0 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (3.14.0)
# Requirement already satisfied: joblib in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (1.5.1)
# Requirement already satisfied: legacy-api-wrap>=1.4.1 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (1.4.1)
# Requirement already satisfied: natsort in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.7.1 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (3.4.2)
# Requirement already satisfied: numba>=0.57.1 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (0.61.2)
# Requirement already satisfied: patsy!=1.0.0 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5.13 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (0.5.13)
# Requirement already satisfied: seaborn>=0.13.2 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (0.13.2)
# Requirement already satisfied: session-info2 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (0.2)
# Requirement already satisfied: statsmodels>=0.14.5 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (0.14.5)
# Requirement already satisfied: tqdm in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (4.67.1)
# Requirement already satisfied: typing-extensions in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (4.14.1)
# Requirement already satisfied: umap-learn>=0.5.6 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scanpy) (0.5.9.post2)
# Requirement already satisfied: beautifulsoup4 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from gdown) (2.32.4)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from anndata>=0.8->scanpy) (1.12.0)
# Requirement already satisfied: exceptiongroup in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from anndata>=0.8->scanpy) (1.3.0)
# Requirement already satisfied: pygsp>=0.5.1 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from graphtools>=1.5.3->phate) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from matplotlib>=3.0->phate) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from matplotlib>=3.0->phate) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from matplotlib>=3.0->phate) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from matplotlib>=3.0->phate) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from matplotlib>=3.0->phate) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from matplotlib>=3.0->phate) (3.2.3)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from numba>=0.57.1->scanpy) (0.44.0)
# Requirement already satisfied: six>=1.5 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.2.0) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from scikit-learn>=0.20.0->phate) (3.6.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from Deprecated->phate) (1.17.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from requests[socks]->gdown) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from requests[socks]->gdown) (2025.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)

# %% [markdown]
# # Dimensionality reduction on the cancer dataset
#
# Goals:
# - Preprocess our raw single cell data
# - Use the processed data to create a continuous latent space via PHATE.
# - Understand how to interpret some of the PHATE parameters and how to choose a good representation of the space.

# %% [markdown]
# <a id='loading'></a>
# ## 1. Downloading the data

# %% [markdown]
# ### Download the cancer data
#
# Alternatively, you may load your own data by replacing the Google Drive file ids with your own file ids.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scanpy as sc

# %matplotlib inline

import phate
import scprep
import os
import gdown

# %%
# Download folder to specific directory
output_dir = "cancer_plasticity"
os.makedirs(output_dir, exist_ok=True)
folder_id = '1maxTkGZxo0cZ7zEW5i3pz2cbFSxdBP-v'
gdown.download_folder(f"https://drive.google.com/drive/folders/{folder_id}", 
                      output=output_dir, quiet=False, use_cookies=False)
# Out:
# Retrieving folder contents
# Retrieving folder 1VUcIZ37OsgJJ1FtFPNrltZRXfo4L0Rct HCC38_2D_culture
# To: /Users/joaofelipe/Yale/Omics Toolbox/4_Code/omics_toolbox/workshops/cancer_plasticity/phate/cancer_plasticity/TSA-48HR_3/matrix.mtx.gz
# 100%|██████████| 47.9M/47.9M [00:04<00:00, 10.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1owdjS3wmKJ89LjoHaiE-sV2xRVZWm_bH
# To: /Users/joaofelipe/Yale/Omics Toolbox/4_Code/omics_toolbox/workshops/cancer_plasticity/phate/cancer_plasticity/TSA-D12/barcodes.tsv.gz
# 100%|██████████| 26.7k/26.7k [00:00<00:00, 1.12MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1LF9l8pGubYbR4ByJ4Z9tRgrHvmKkY00D
# To: /Users/joaofelipe/Yale/Omics Toolbox/4_Code/omics_toolbox/workshops/cancer_plasticity/phate/cancer_plasticity/TSA-D12/features.tsv.gz
# 100%|██████████| 305k/305k [00:00<00:00, 2.65MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=11LgwQeEnm_U19h1wFxGq3sEMXLxG-4Tr
# From (redirected): https://drive.google.com/uc?id=11LgwQeEnm_U19h1wFxGq3sEMXLxG-4Tr&confirm=t&uuid=d96c8ce8-d3ba-4715-8928-eae04778c14e
# To: /Users/joaofelipe/Yale/Omics Toolbox/4_Code/omics_toolbox/workshops/cancer_plasticity/phate/cancer_plasticity/TSA-D12/matrix.mtx.gz
# 100%|██████████| 61.7M/61.7M [00:05<00:00, 11.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1BaKPOvuaJBrAR8WvXvHt0qak7XE_tQrW
# To: /Users/joaofelipe/Yale/Omics Toolbox/4_Code/omics_toolbox/workshops/cancer_plasticity/phate/cancer_plasticity/TSA-D18/barcodes.tsv.gz
# 100%|██████████| 24.0k/24.0k [00:00<00:00, 1.32MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1WP4gdRnMAhh_VpqDmvn-C8DBaJD_Bfo5
# To: /Users/joaofelipe/Yale/Omics Toolbox/4_Code/omics_toolbox/workshops/cancer_plasticity/phate/cancer_plasticity/TSA-D18/features.tsv.gz
# 100%|██████████| 305k/305k [00:00<00:00, 3.99MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1Xdobp-W7AfnBxRCnans4Wd1mBFTAlmZs
# From (redirected): https://drive.google.com/uc?id=1Xdobp-W7AfnBxRCnans4Wd1mBFTAlmZs&confirm=t&uuid=4434a9ca-3125-4f50-84c9-4cdf9789db39
# To: /Users/joaofelipe/Yale/Omics Toolbox/4_Code/omics_toolbox/workshops/cancer_plasticity/phate/cancer_plasticity/TSA-D18/matrix.mtx.gz
# 100%|██████████| 57.1M/57.1M [00:05<00:00, 10.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1KmbI7ygYU8bW7bPelaIQijj4yq9zxo6Y
# To: /Users/joaofelipe/Yale/Omics Toolbox/4_Code/omics_toolbox/workshops/cancer_plasticity/phate/cancer_plasticity/TSA-D30/barcodes.tsv.gz
# 100%|██████████| 27.3k/27.3k [00:00<00:00, 1.48MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1CFW8skZYCTCosCGrEwQtwcKXoS4Vct4H
# To: /Users/joaofelipe/Yale/Omics Toolbox/4_Code/omics_toolbox/workshops/cancer_plasticity/phate/cancer_plasticity/TSA-D30/features.tsv.gz
# 100%|██████████| 305k/305k [00:00<00:00, 2.63MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1TFJIMO0ue7x2d32lYK4DEQo5-RiVHkzo
# From (redirected): https://drive.google.com/uc?id=1TFJIMO0ue7x2d32lYK4DEQo5-RiVHkzo&confirm=t&uuid=900780c4-bef7-41c6-9b31-dda1c689a27f
# To: /Users/joaofelipe/Yale/Omics Toolbox/4_Code/omics_toolbox/workshops/cancer_plasticity/phate/cancer_plasticity/TSA-D30/matrix.mtx.gz
# 100%|██████████| 54.6M/54.6M [00:04<00:00, 11.4MB/s]
# Download completed
# ['cancer_plasticity/HCC38_2D_culture/barcodes.tsv.gz',
#  'cancer_plasticity/HCC38_2D_culture/features.tsv.gz',
#  'cancer_plasticity/HCC38_2D_culture/matrix.mtx.gz',
#  'cancer_plasticity/TSA-48HR_3/barcodes.tsv.gz',
#  'cancer_plasticity/TSA-48HR_3/features.tsv.gz',
#  'cancer_plasticity/TSA-48HR_3/matrix.mtx.gz',
#  'cancer_plasticity/TSA-D12/barcodes.tsv.gz',
#  'cancer_plasticity/TSA-D12/features.tsv.gz',
#  'cancer_plasticity/TSA-D12/matrix.mtx.gz',
#  'cancer_plasticity/TSA-D18/barcodes.tsv.gz',
#  'cancer_plasticity/TSA-D18/features.tsv.gz',
#  'cancer_plasticity/TSA-D18/matrix.mtx.gz',
#  'cancer_plasticity/TSA-D30/barcodes.tsv.gz',
#  'cancer_plasticity/TSA-D30/features.tsv.gz',
#  'cancer_plasticity/TSA-D30/matrix.mtx.gz']

# %% [markdown]
# Here we are loading the data into Python objects called: T1,T2,T3,T4,T5.
#
# The sparse=True is necessary to keep the data in a "sparse" format (full of zeros). This will use way less space in the computer memory.

# %%
sparse=True
#scprep has a function that handles transforming the outputs from the 10x machine into Pandas DataFrames
T1 = scprep.io.load_10X(os.path.join("cancer_plasticity","HCC38_2D_culture"), sparse=sparse, gene_labels='both')
T2 = scprep.io.load_10X(os.path.join("cancer_plasticity","TSA-48HR_3"), sparse=sparse, gene_labels='both')
T3 = scprep.io.load_10X(os.path.join("cancer_plasticity","TSA-D12"), sparse=sparse, gene_labels='both')
T4 = scprep.io.load_10X(os.path.join("cancer_plasticity","TSA-D18"), sparse=sparse, gene_labels='both')
T5 = scprep.io.load_10X(os.path.join("cancer_plasticity","TSA-D30"), sparse=sparse, gene_labels='both')
T1.head() #We will visualize how the data looks
# Out:
#                     MIR1302-2HG (ENSG00000243485)  FAM138A (ENSG00000237613)  \
# 0
# AAACCTGAGAAGGTTT-1                            0.0                        0.0
# AAACCTGAGTTCGCGC-1                            0.0                        0.0
# AAACCTGCAGCTTAAC-1                            0.0                        0.0
# AAACCTGCAGGACCCT-1                            0.0                        0.0
# AAACCTGCATGTTGAC-1                            0.0                        0.0
#
#                     OR4F5 (ENSG00000186092)  AL627309.1 (ENSG00000238009)  \
# 0
# AAACCTGAGAAGGTTT-1                      0.0                           0.0
# AAACCTGAGTTCGCGC-1                      0.0                           0.0
# AAACCTGCAGCTTAAC-1                      0.0                           0.0
# AAACCTGCAGGACCCT-1                      0.0                           0.0
# AAACCTGCATGTTGAC-1                      0.0                           0.0
#
#                     AL627309.3 (ENSG00000239945)  \
# 0
# AAACCTGAGAAGGTTT-1                           0.0
# AAACCTGAGTTCGCGC-1                           0.0
# AAACCTGCAGCTTAAC-1                           0.0
# AAACCTGCAGGACCCT-1                           0.0
# AAACCTGCATGTTGAC-1                           0.0
#
#                     AL627309.2 (ENSG00000239906)  \
# 0
# AAACCTGAGAAGGTTT-1                           0.0
# AAACCTGAGTTCGCGC-1                           0.0
# AAACCTGCAGCTTAAC-1                           0.0
# AAACCTGCAGGACCCT-1                           0.0
# AAACCTGCATGTTGAC-1                           0.0
#
#                     AL627309.4 (ENSG00000241599)  \
# 0
# AAACCTGAGAAGGTTT-1                           0.0
# AAACCTGAGTTCGCGC-1                           0.0
# AAACCTGCAGCTTAAC-1                           0.0
# AAACCTGCAGGACCCT-1                           0.0
# AAACCTGCATGTTGAC-1                           0.0
#
#                     AL732372.1 (ENSG00000236601)  OR4F29 (ENSG00000284733)  \
# 0
# AAACCTGAGAAGGTTT-1                           0.0                       0.0
# AAACCTGAGTTCGCGC-1                           0.0                       0.0
# AAACCTGCAGCTTAAC-1                           0.0                       0.0
# AAACCTGCAGGACCCT-1                           0.0                       0.0
# AAACCTGCATGTTGAC-1                           0.0                       0.0
#
#                     AC114498.1 (ENSG00000235146)  ...  \
# 0                                                 ...
# AAACCTGAGAAGGTTT-1                           0.0  ...
# AAACCTGAGTTCGCGC-1                           0.0  ...
# AAACCTGCAGCTTAAC-1                           0.0  ...
# AAACCTGCAGGACCCT-1                           0.0  ...
# AAACCTGCATGTTGAC-1                           0.0  ...
#
#                     AC007325.2 (ENSG00000277196)  \
# 0
# AAACCTGAGAAGGTTT-1                           0.0
# AAACCTGAGTTCGCGC-1                           0.0
# AAACCTGCAGCTTAAC-1                           0.0
# AAACCTGCAGGACCCT-1                           0.0
# AAACCTGCATGTTGAC-1                           0.0
#
#                     BX072566.1 (ENSG00000277630)  \
# 0
# AAACCTGAGAAGGTTT-1                           0.0
# AAACCTGAGTTCGCGC-1                           0.0
# AAACCTGCAGCTTAAC-1                           0.0
# AAACCTGCAGGACCCT-1                           0.0
# AAACCTGCATGTTGAC-1                           0.0
#
#                     AL354822.1 (ENSG00000278384)  \
# 0
# AAACCTGAGAAGGTTT-1                           0.0
# AAACCTGAGTTCGCGC-1                           0.0
# AAACCTGCAGCTTAAC-1                           0.0
# AAACCTGCAGGACCCT-1                           0.0
# AAACCTGCATGTTGAC-1                           0.0
#
#                     AC023491.2 (ENSG00000278633)  \
# 0
# AAACCTGAGAAGGTTT-1                           0.0
# AAACCTGAGTTCGCGC-1                           0.0
# AAACCTGCAGCTTAAC-1                           0.0
# AAACCTGCAGGACCCT-1                           0.0
# AAACCTGCATGTTGAC-1                           0.0
#
#                     AC004556.1 (ENSG00000276345)  \
# 0
# AAACCTGAGAAGGTTT-1                           0.0
# AAACCTGAGTTCGCGC-1                           0.0
# AAACCTGCAGCTTAAC-1                           0.0
# AAACCTGCAGGACCCT-1                           0.0
# AAACCTGCATGTTGAC-1                           0.0
#
#                     AC233755.2 (ENSG00000277856)  \
# 0
# AAACCTGAGAAGGTTT-1                           0.0
# AAACCTGAGTTCGCGC-1                           0.0
# AAACCTGCAGCTTAAC-1                           0.0
# AAACCTGCAGGACCCT-1                           0.0
# AAACCTGCATGTTGAC-1                           0.0
#
#                     AC233755.1 (ENSG00000275063)  \
# 0
# AAACCTGAGAAGGTTT-1                           0.0
# AAACCTGAGTTCGCGC-1                           0.0
# AAACCTGCAGCTTAAC-1                           0.0
# AAACCTGCAGGACCCT-1                           0.0
# AAACCTGCATGTTGAC-1                           0.0
#
#                     AC240274.1 (ENSG00000271254)  \
# 0
# AAACCTGAGAAGGTTT-1                           0.0
# AAACCTGAGTTCGCGC-1                           0.0
# AAACCTGCAGCTTAAC-1                           0.0
# AAACCTGCAGGACCCT-1                           0.0
# AAACCTGCATGTTGAC-1                           0.0
#
#                     AC213203.1 (ENSG00000277475)  FAM231C (ENSG00000268674)
# 0
# AAACCTGAGAAGGTTT-1                           0.0                        0.0
# AAACCTGAGTTCGCGC-1                           0.0                        0.0
# AAACCTGCAGCTTAAC-1                           0.0                        0.0
# AAACCTGCAGGACCCT-1                           0.0                        0.0
# AAACCTGCATGTTGAC-1                           0.0                        0.0
#
# [5 rows x 33538 columns]

# %% [markdown]
# <a id='preprocessing'></a>
# ## 2. Preprocessing: Filtering, Normalizing, and Transforming
#
#
# We filter the data by:
# 1. Filtering by library size (if we did not do this prior to combining batches)
# 2. Removing genes that are expressed in relatively few cells.
# 3. Removing dead cells
#
# We filter dead cells after library size normalization, since library size is not necessarily related to cell state.

# %% [markdown]
# #### Filtering I. Library size filtering
#
# Library size is the total sum of gene counts in a cell.
#
# We filter out cells that have either very large or very small library sizes. For this data set, library size correlates somewhat with sample and so we filter on a per-sample basis. In this case, we eliminate the top and bottom 20% of cells for each sample. Similar results are obtained with simpler, less conservative filtering.

# %%
# Visualize the parts of the data we will drop.
# We will keep drop the bellow 20 and above 80 percentiles.
scprep.plot.plot_library_size(T1, percentile=[10,90]) #Try changing T1 for other timepoints, they should follow more or less a common distribution.
# Out:
# /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# <Axes: xlabel='Library size', ylabel='Number of cells'>

# %% [markdown]
# Since our data set are really big, it's good for us to filter each batch by itself before joining them together.
# The loop bellow is just filtering each batch by itself.

# %%
filtered_batches = []
for batch in [T1, T2, T3, T4, T5]:
    batch = scprep.filter.filter_library_size(batch, percentile=20, keep_cells='above')
    batch = scprep.filter.filter_library_size(batch, percentile=80, keep_cells='below')
    filtered_batches.append(batch)
    del batch
del T1, T2, T3, T4, T5 # removes objects from memory

# %% [markdown]
# Now, we can merge all datasets together and start treating the entire dataset as a single one.
# To keep track of which timepoint is each, we create a sample_labels object, that contains our data information.

# %%
data, sample_labels = scprep.utils.combine_batches(
    filtered_batches, 
    ["Day 0", "Day 2", "Day 12", "Day 18", "Day 30"],
    append_to_cell_names=True
)
del filtered_batches # removes all the batches from memory, since we already have all them in the _data_ object
data.head()
# Out:
#                           A1BG (ENSG00000121410)  A1BG-AS1 (ENSG00000268895)  \
# AAACCTGAGTTCGCGC-1_Day 0                     2.0                         0.0
# AAACCTGCAGGACCCT-1_Day 0                     0.0                         0.0
# AAACCTGCATGTTGAC-1_Day 0                     2.0                         0.0
# AAACCTGGTCGAACAG-1_Day 0                     1.0                         0.0
# AAACCTGTCCGTTGCT-1_Day 0                     1.0                         0.0
#
#                           A1CF (ENSG00000148584)  A2M (ENSG00000175899)  \
# AAACCTGAGTTCGCGC-1_Day 0                     0.0                    0.0
# AAACCTGCAGGACCCT-1_Day 0                     0.0                    0.0
# AAACCTGCATGTTGAC-1_Day 0                     0.0                    0.0
# AAACCTGGTCGAACAG-1_Day 0                     0.0                    0.0
# AAACCTGTCCGTTGCT-1_Day 0                     0.0                    0.0
#
#                           A2M-AS1 (ENSG00000245105)  A2ML1 (ENSG00000166535)  \
# AAACCTGAGTTCGCGC-1_Day 0                        0.0                      0.0
# AAACCTGCAGGACCCT-1_Day 0                        0.0                      0.0
# AAACCTGCATGTTGAC-1_Day 0                        0.0                      0.0
# AAACCTGGTCGAACAG-1_Day 0                        0.0                      0.0
# AAACCTGTCCGTTGCT-1_Day 0                        0.0                      0.0
#
#                           A2ML1-AS1 (ENSG00000256661)  \
# AAACCTGAGTTCGCGC-1_Day 0                          0.0
# AAACCTGCAGGACCCT-1_Day 0                          0.0
# AAACCTGCATGTTGAC-1_Day 0                          0.0
# AAACCTGGTCGAACAG-1_Day 0                          0.0
# AAACCTGTCCGTTGCT-1_Day 0                          0.0
#
#                           A2ML1-AS2 (ENSG00000256904)  \
# AAACCTGAGTTCGCGC-1_Day 0                          0.0
# AAACCTGCAGGACCCT-1_Day 0                          0.0
# AAACCTGCATGTTGAC-1_Day 0                          0.0
# AAACCTGGTCGAACAG-1_Day 0                          0.0
# AAACCTGTCCGTTGCT-1_Day 0                          0.0
#
#                           A3GALT2 (ENSG00000184389)  A4GALT (ENSG00000128274)  \
# AAACCTGAGTTCGCGC-1_Day 0                        0.0                       0.0
# AAACCTGCAGGACCCT-1_Day 0                        0.0                       0.0
# AAACCTGCATGTTGAC-1_Day 0                        0.0                       0.0
# AAACCTGGTCGAACAG-1_Day 0                        0.0                       0.0
# AAACCTGTCCGTTGCT-1_Day 0                        0.0                       0.0
#
#                           ...  ZWILCH (ENSG00000174442)  \
# AAACCTGAGTTCGCGC-1_Day 0  ...                       1.0
# AAACCTGCAGGACCCT-1_Day 0  ...                       0.0
# AAACCTGCATGTTGAC-1_Day 0  ...                       0.0
# AAACCTGGTCGAACAG-1_Day 0  ...                       0.0
# AAACCTGTCCGTTGCT-1_Day 0  ...                       0.0
#
#                           ZWINT (ENSG00000122952)  ZXDA (ENSG00000198205)  \
# AAACCTGAGTTCGCGC-1_Day 0                      5.0                     0.0
# AAACCTGCAGGACCCT-1_Day 0                      0.0                     0.0
# AAACCTGCATGTTGAC-1_Day 0                      0.0                     0.0
# AAACCTGGTCGAACAG-1_Day 0                      0.0                     0.0
# AAACCTGTCCGTTGCT-1_Day 0                      0.0                     0.0
#
#                           ZXDB (ENSG00000198455)  ZXDC (ENSG00000070476)  \
# AAACCTGAGTTCGCGC-1_Day 0                     0.0                     0.0
# AAACCTGCAGGACCCT-1_Day 0                     0.0                     0.0
# AAACCTGCATGTTGAC-1_Day 0                     0.0                     0.0
# AAACCTGGTCGAACAG-1_Day 0                     0.0                     0.0
# AAACCTGTCCGTTGCT-1_Day 0                     0.0                     0.0
#
#                           ZYG11A (ENSG00000203995)  ZYG11B (ENSG00000162378)  \
# AAACCTGAGTTCGCGC-1_Day 0                       0.0                       0.0
# AAACCTGCAGGACCCT-1_Day 0                       0.0                       0.0
# AAACCTGCATGTTGAC-1_Day 0                       0.0                       0.0
# AAACCTGGTCGAACAG-1_Day 0                       0.0                       0.0
# AAACCTGTCCGTTGCT-1_Day 0                       0.0                       0.0
#
#                           ZYX (ENSG00000159840)  ZZEF1 (ENSG00000074755)  \
# AAACCTGAGTTCGCGC-1_Day 0                    1.0                      0.0
# AAACCTGCAGGACCCT-1_Day 0                    1.0                      0.0
# AAACCTGCATGTTGAC-1_Day 0                    2.0                      0.0
# AAACCTGGTCGAACAG-1_Day 0                    0.0                      0.0
# AAACCTGTCCGTTGCT-1_Day 0                    0.0                      0.0
#
#                           hsa-mir-1253 (ENSG00000272920)
# AAACCTGAGTTCGCGC-1_Day 0                             0.0
# AAACCTGCAGGACCCT-1_Day 0                             0.0
# AAACCTGCATGTTGAC-1_Day 0                             0.0
# AAACCTGGTCGAACAG-1_Day 0                             0.0
# AAACCTGTCCGTTGCT-1_Day 0                             0.0
#
# [5 rows x 33538 columns]

# %% [markdown]
# ### Filtering II. Remove rare genes
#
# We eliminate genes that are expressed in 10 cells or fewer, they usually bring no information and increase the dimentionality of our data.
#
# We are removing genes that appear in less than 10 cells.

# %%
data = scprep.filter.filter_rare_genes(data, min_cells=10)

# %% [markdown]
# ### Normalization I. Library Size normalization
#
# To correct for differences in library sizes, we divide each cell by its library size and then rescale by the median library size.
#
# In python this is performed using the preprocessing method `library_size_normalize()`.

# %%
data = scprep.normalize.library_size_normalize(data)

# %% [markdown]
# #### Filtering III: Dead cell removal
#
# Dead cells are likely to have a higher mitochondrial RNA expression level than live cells. Therefore, we remove suspected dead cells by eliminating cells that have the highest mitochondrial RNA expression levels on average.
#
# First let's look at the distribution of mitochontrial genes.

# %%
mito_genes = scprep.select.get_gene_set(data, starts_with="MT-") # Get all mitochondrial genes. There are 14, FYI.
scprep.plot.plot_gene_set_expression(data, genes=mito_genes, percentile=90)
# Out:
# /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# <Axes: xlabel='Gene expression', ylabel='Number of cells'>

# %% [markdown]
# Here we see that above the top 90th percentile, there is a steep increase in expression of mitochondrial RNAs. We'll remove these cells from further analysis.

# %%
data, sample_labels = scprep.filter.filter_gene_set_expression(
    data, sample_labels, genes=mito_genes, 
    percentile=90, keep_cells='below')

# %% [markdown]
# ### Transformation I. Sqrt Transformation
#
# In scRNA-seq analysis, the data is often $\log$-transformed. This typically requires the addition of some small value to avoid taking $\log(0)$. We avoid this issue entirely by instead taking the square root transform. The square root function has a similar form as the $\log$ function with the added benefit of being stable at 0.

# %%
data = scprep.transform.sqrt(data)

# %%
data
# Out:
#                            A1BG (ENSG00000121410)  A1BG-AS1 (ENSG00000268895)  \
# AAACCTGAGTTCGCGC-1_Day 0                 1.246451                         0.0
# AAACCTGCAGGACCCT-1_Day 0                 0.000000                         0.0
# AAACCTGCATGTTGAC-1_Day 0                 1.357688                         0.0
# AAACCTGGTCGAACAG-1_Day 0                 1.094351                         0.0
# AAACCTGTCCGTTGCT-1_Day 0                 1.160205                         0.0
# ...                                           ...                         ...
# TTTGGTTAGATGTGGC-1_Day 30                1.016762                         0.0
# TTTGGTTGTACCGGCT-1_Day 30                0.744839                         0.0
# AAACCTGGTCGAACAG-1_Day 0                      0.0                       0.0
# AAACCTGTCCGTTGCT-1_Day 0                      0.0                       0.0
# ...                                           ...                       ...
# TTTGGTTAGATGTGGC-1_Day 30                     0.0                       0.0
# TTTGGTTGTACCGGCT-1_Day 30                     0.0                       0.0
# TTTGGTTTCAAAGTAG-1_Day 30                     0.0                       0.0
# TTTGGTTTCTGCGGCA-1_Day 30                     0.0                       0.0
# TTTGTCAGTTCCACGG-1_Day 30                     0.0                       0.0
#
#                            ZYG11B (ENSG00000162378)  ZYX (ENSG00000159840)  \
# AAACCTGAGTTCGCGC-1_Day 0                        0.0               0.881374
# AAACCTGCAGGACCCT-1_Day 0                        0.0               0.893855
# AAACCTGCATGTTGAC-1_Day 0                        0.0               1.357688
# AAACCTGGTCGAACAG-1_Day 0                        0.0               0.000000
# AAACCTGTCCGTTGCT-1_Day 0                        0.0               0.000000
# ...                                             ...                    ...
# TTTGGTTAGATGTGGC-1_Day 30                       0.0               1.016762
# TTTGGTTGTACCGGCT-1_Day 30                       0.0               0.744839
# TTTGGTTTCAAAGTAG-1_Day 30                       0.0               0.000000
# TTTGGTTTCTGCGGCA-1_Day 30                       0.0               0.000000
# TTTGTCAGTTCCACGG-1_Day 30                       0.0               0.878139
#
#                            ZZEF1 (ENSG00000074755)
# AAACCTGAGTTCGCGC-1_Day 0                  0.000000
# AAACCTGCAGGACCCT-1_Day 0                  0.000000
# AAACCTGCATGTTGAC-1_Day 0                  0.000000
# AAACCTGGTCGAACAG-1_Day 0                  0.000000
# AAACCTGTCCGTTGCT-1_Day 0                  0.000000
# ...                                            ...
# TTTGGTTAGATGTGGC-1_Day 30                 0.000000
# TTTGGTTGTACCGGCT-1_Day 30                 0.000000
# TTTGGTTTCAAAGTAG-1_Day 30                 0.000000
# TTTGGTTTCTGCGGCA-1_Day 30                 0.986623
# TTTGTCAGTTCCACGG-1_Day 30                 0.000000
#
# [12773 rows x 18989 columns]

# %% [markdown]
# ## 3. Visualization using Principle Components Analysis (PCA)
#
# Here we're going to use the simplest dimensionality reduction method first. We don't expect PCA to work well because the dataset is so complex, but it's a good place to start with any dataset.

# %% [markdown]
# #### Running PCA on the EB data

# %%
data_pca = scprep.reduce.pca(data, n_components=200, method='dense')

# %%
data_pca.head()
# Out:
#                                 PC1        PC2        PC3       PC4       PC5  \
# AAACCTGAGTTCGCGC-1_Day 0  -1.711378  12.267954 -17.950996  1.514687  6.146578
# AAACCTGCAGGACCCT-1_Day 0  -9.395385  16.200584 -10.780515 -2.952575  2.920742
# AAACCTGCATGTTGAC-1_Day 0   7.437381  15.321024  -7.410342  5.883192  7.345741
# AAACCTGGTCGAACAG-1_Day 0   3.329705  10.178568 -10.345435 -7.002020  1.424237
# AAACCTGTCCGTTGCT-1_Day 0  10.382003  20.882404  -3.431428  7.961390  9.013776
#
#                                 PC6       PC7       PC8       PC9      PC10  \
# AAACCTGAGTTCGCGC-1_Day 0  -1.434702 -4.146762 -4.150688 -6.836263  1.386650
# AAACCTGCAGGACCCT-1_Day 0  -3.745081 -7.269115  1.645589  0.127643  1.508349
# AAACCTGCATGTTGAC-1_Day 0 -12.649867 -5.190435 -4.618985 -1.566828  2.783859
# AAACCTGGTCGAACAG-1_Day 0  -6.254788 -5.504434 -9.746510  2.086918 -2.258232
# AAACCTGTCCGTTGCT-1_Day 0  -1.100926 -7.548623 -4.950447 -2.478590 -4.860534
#
#                           ...     PC191     PC192     PC193     PC194  \
# AAACCTGAGTTCGCGC-1_Day 0  ... -1.638006  0.468690 -0.392639  0.230995
# AAACCTGCAGGACCCT-1_Day 0  ... -0.391024  0.448683  0.029013 -0.256914
# AAACCTGCATGTTGAC-1_Day 0  ...  0.186687  0.980845 -0.094299 -0.845212
# AAACCTGGTCGAACAG-1_Day 0  ...  0.924404 -1.471301  1.694795  1.312713
# AAACCTGTCCGTTGCT-1_Day 0  ... -1.326178 -0.844140  2.562842 -1.959928
#
#                              PC195     PC196     PC197     PC198     PC199  \
# AAACCTGAGTTCGCGC-1_Day 0 -1.360328  1.456887  1.249632 -1.094730  0.435509
# AAACCTGCAGGACCCT-1_Day 0 -0.805585 -0.536741  0.552004 -0.359314  0.023197
# AAACCTGCATGTTGAC-1_Day 0 -0.066385 -0.519978 -0.680898  1.027651  2.412364
# AAACCTGGTCGAACAG-1_Day 0 -1.112954  1.076677  0.727383 -0.059638 -0.177697
# AAACCTGTCCGTTGCT-1_Day 0 -1.875920 -0.006960  2.412397  1.576667  1.507109
#
#                              PC200
# AAACCTGAGTTCGCGC-1_Day 0  0.239505
# AAACCTGCAGGACCCT-1_Day 0 -0.181931
# AAACCTGCATGTTGAC-1_Day 0 -0.485360
# AAACCTGGTCGAACAG-1_Day 0 -0.701354
# AAACCTGTCCGTTGCT-1_Day 0  0.271174
#
# [5 rows x 200 columns]

# %% [markdown]
# #### Plotting PCs using `scprep.plot`
#
# The scprep package has a number of handy plotting features that act as a wrapper to `matplotlib`. You should know how to use `matplotlib` for more complicated plotting, but you can make all the plots we need in this tutorial with some help from `scprep`.
#
# The full documentaiton of `scprep.plot` can be found here:
#
# https://scprep.readthedocs.io/en/stable/reference.html#module-scprep.plot

# %%
# Create a figure (the background) and a set of axes (the things we plot on)
fig, axes = plt.subplots(2,3, figsize=(12,8))
# This makes it easier to iterate through the axes
axes = axes.flatten()

for i, ax in enumerate(axes):
    # only plot a legend on one axis
    legend = True if i == 2 else False
    # There are a lot of parameters here, you can find the full scatter documentation at
    # https://scprep.readthedocs.io/en/stable/reference.html#scprep.plot.scatter
    scprep.plot.scatter(data_pca.iloc[:,i], data_pca.iloc[:,i+1], c=sample_labels,
                        cmap='Spectral', ax=ax,
                        label_prefix="PC", legend=legend)
fig.tight_layout()

# %% [markdown]
# #### Plotting expression of a gene on the first two PCs
#
# Now let's plot expression of some genes!

# %%
gene = 'ZEB1'

expression = scprep.select.select_cols(data, exact_word=gene)

# we will sort cells by maximum expression so we can see where the gene is expressed
sort_index = expression.sort_values().index

scprep.plot.scatter2d(data_pca.loc[sort_index], c=expression.loc[sort_index], shuffle=False,
                     title=gene, ticks=None, label_prefix='PC')
# Out:
# /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# <Axes: title={'center': 'ZEB1'}, xlabel='PC1', ylabel='PC2'>

# %%
gene = 'VIM'

# ================
# Sort cells by maximum expression of ACTB and plot the result on PCA
expression = scprep.select.select_cols(data, exact_word=gene)

sort_index = expression.sort_values().index

scprep.plot.scatter2d(data_pca.loc[sort_index], c=expression.loc[sort_index], shuffle=False,
                     title=gene, ticks=None, label_prefix='PC')
# ===============
# Out:
# /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# <Axes: title={'center': 'VIM'}, xlabel='PC1', ylabel='PC2'>

# %%
gene = 'CDH1'

# ================
# Sort cells by maximum expression of HAND1 and plot the result on PCA
expression = scprep.select.select_cols(data, exact_word=gene)

sort_index = expression.sort_values().index

scprep.plot.scatter2d(data_pca.loc[sort_index], c=expression.loc[sort_index], shuffle=False,
                     title=gene, ticks=None, label_prefix='PC')
# ===============
# Out:
# /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# <Axes: title={'center': 'CDH1'}, xlabel='PC1', ylabel='PC2'>

# %% [markdown]
# ### Discussion
# # TODO: MODIFY DISCUSSION
# 1. What do you notice? What does the first principle component track with? What about the second? What do you think the higher PCs represent? What does that mean?
#
# The first principal components tracks with sample time. The second expands as sample time increases, indicating some kind of cellular heterogeneity marker.
#
# Higher PCs are likely to represent specific differences between cell types.
#
# 2. Why did we plot gene expression on the first two PCs?
#
# The first two PCs represents the highest level structure of the data, so gene expression plotted on this gives us a broad understanding of what's happening in the data. The genes allows us to characterize each part of the manifold.
#
# 3. Look up the function of these genes. What do you notice about where these genes are expressed? What does it mean when a gene is expressed everywhere vs. in one region?
#
# If a gene is expressed everywhere, it is likely some kind of housekeeping gene (indeed, Beta-actin is a part of the cell cytoskeleton and is expressed in all human cells.) If a gene is only expression in one region, it's likely to be cell-type specific, like HAND1 which is a heart / neural crest marker.

# %% [markdown]
# ## 4. Embedding Data Using PHATE

# %% [markdown]
# #### How does PHATE work?
#
# PHATE is a dimensionaltiy reduction developed by the Krishnaswamy lab for visualizing high-dimensional data. We use PHATE for *every* dataset the comes through the lab: scRNA-seq, CyTOF, gut microbiome profiles, simulated data, etc. PHATE was designed to handle noisy, non-linear relationships between data points. PHATE produces a low-dimensional representation that preserves both local and global structure in a dataset so that you can make generate hypotheses from the plot about the relationships between cells present in a dataset. Although PHATE has utility for analysis of many data modalities, we will focus on the application of PHATE for scRNA-seq analysis.
#
# PHATE is inspired by diffusion maps [(Coifman et al. 2008.)](https://doi.org/10.1016/j.acha.2006.04.006), but include several key innovations that make it possible to generate a two or three dimensional visualization that preserves continuous relationships between cells where they exist. For a full explanation of the PHATE algorithm, please consult [the PHATE manuscript](https://doi.org/10.1101/120378).

# %% [markdown]
# #### Using the PHATE estimator
#
# The API of PHATE models that of Scikit Learn. First, you instantiate a PHATE estimator object with the parameters for fitting the PHATE embedding to a given dataset. Next, you use the `fit` and `fit_transform` functions to generate an embedding. For more information, check out [**the PHATE readthedocs page**](http://phate.readthedocs.io/).
#
# PHATE has it's own set of hyperparameters. Changing the parameters will greatly change the output of the algorithm. We reccomend starting with the defaults, then change `knn` and `decay` according the reccomendations below. Generally, we won't select `t` ourselves, but if you're tuning hyperparameters, it's best to fix `t`.
#
# * `knn` : Number of nearest neighbors (default: 5). Increase this (e.g. to 20) if your PHATE embedding appears very disconnected. You should also consider increasing `k` if your dataset is extremely large (e.g. >100k cells)
# * `decay` : Alpha decay (default: 15). Decreasing `a` increases connectivity on the graph, increasing `a` decreases connectivity. This rarely needs to be tuned. Set it to `None` for a k-nearest neighbors kernel.
# * `t` : Number of times to power the operator (default: 'auto'). This is equivalent to the amount of smoothing done to the data. It is chosen automatically by default, but you can increase it if your embedding lacks structure, or decrease it if the structure looks too compact.
# * `gamma` : Informational distance constant (default: 1). `gamma=1` gives the PHATE log potential, but other informational distances can be interesting. If most of the points seem concentrated in one section of the plot, you can try `gamma=0`.

# %% [markdown]
# Here's the simplest way to apply PHATE. Running this should take ~1-3 minutes.

# %%
phate_op = phate.PHATE(knn=5, n_jobs=-2)

data_phate = phate_op.fit_transform(data_pca.iloc[:,:50])
data_phate = pd.DataFrame(data_phate, index=data.index)
# Out:
# Calculating PHATE...
#   Running PHATE on 12773 observations and 50 variables.
#   Calculating graph and diffusion operator...
#     Calculating KNN search...
#     Calculated KNN search in 2.20 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.04 seconds.
#   Calculated graph and diffusion operator in 2.25 seconds.
#   Calculating landmark operator...
#     Calculating SVD...
#     Calculated SVD in 0.34 seconds.
#     Calculating KMeans...
#     Calculated KMeans in 1.89 seconds.
#   Calculated landmark operator in 2.56 seconds.
#   Calculating optimal t...
#     Automatically selected t = 24
#   Calculated optimal t in 1.17 seconds.
#   Calculating diffusion potential...
#   Calculated diffusion potential in 0.31 seconds.
#   Calculating metric MDS...
#   Calculated metric MDS in 1.91 seconds.
# Calculated PHATE in 8.20 seconds.

# %% [markdown]
# And then we plot using `scprep.plot.scatter2d`. For more advanced plotting, we recommend Matplotlib. If you want more help on using Matplotlib, they have [**extensive documentation**](https://matplotlib.org/tutorials/index.html) and [**many Stackoverflow threads**](https://stackoverflow.com/questions/tagged/matplotlib).

# %%
# ================
# Plot the PHATE coordinates
# colored by time point
scprep.plot.scatter2d(data_phate, c=sample_labels, cmap='Spectral', 
                      ticks=False, label_prefix='PHATE',
                      legend_anchor=(1,1), figsize=(7,5))
# ================
# Out:
# /Users/joaofelipe/miniconda3/envs/omics-toolbox/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# <Axes: xlabel='PHATE1', ylabel='PHATE2'>

# %% [markdown]
# #### Gene visualization

# %%
# ================
# Plot three subplots of the PHATE coordinates
# coloring by ACTB, SOX10 and HAND1
genes_for_plotting = ['ZEB1','VIM','CDH1']

fig, axes = plt.subplots(1,3, figsize=(14,4))
axes = axes.flatten()

for gene, ax in zip(genes_for_plotting, axes.flatten()):
    expression = scprep.select.select_cols(data, exact_word=gene)
    
    sort_index = expression.sort_values().index
    
    scprep.plot.scatter2d(data_phate.loc[sort_index], c=expression.loc[sort_index], shuffle=False,
                         title=gene, ticks=None, label_prefix='PHATE', ax=ax)

fig.tight_layout()
# ================

# %% [markdown]
# ### Discussion
# # TODO:CREATE QUESTIONS
# In groups, discuss the following questions:
# 1. In a dataset with trajectories, how well does each method perform?
#
#
# 2. Now that you've seen all the methods, how might you include them in a workflow?
#
#
# 3. What are the advantages of each method?
#
#
# 4. If you didn't know if your data contained clusters or trajectories, what would you do?
